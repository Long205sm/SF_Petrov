# %%
import pandas as pd

# %%
import numpy as np


def random_predict(number: int = 1) -> int:

    count = 0
    predict_number = 50

    while number != predict_number:
        count += 1
        #predict_number = np.random.randint(1, 101)  # предполагаемое число
        if number > predict_number:
            predict_number = predict_number + (predict_number // 2)
            print(predict_number, 'больше')
        if number < predict_number:
                predict_number -= 1
                print(predict_number, 'меньше') 
        if number == predict_number:
            break  # выход из цикла если угадали
    return count

print(f'Кол-во попыток: {random_predict(80)}')
# Out:
# 75 больше
# 112 больше
# 111 меньше
# 110 меньше
# 109 меньше
# 108 меньше
# 107 меньше
# 106 меньше
# 105 меньше
# 104 меньше
# 103 меньше
# 102 меньше
# 101 меньше
# 100 меньше
# 99 меньше
# 98 меньше
# 97 меньше
# 96 меньше
# 95 меньше
# 94 меньше
# 93 меньше
# 92 меньше
# 91 меньше
# 90 меньше
# 89 меньше
# 88 меньше
# 87 меньше
# 86 меньше
# 85 меньше
# 84 меньше
# 83 меньше
# 82 меньше
# 81 меньше
# 80 меньше
# Кол-во попыток: 33

# %%
import numpy as np


def random_predict(number: int = 1) -> int:

    count = 0
    predict_number = 50

    #while True:
    #    count += 1
    #    predict_number = np.random.randint(1, 101)  # предполагаемое число
    while number != predict_number:
        count += 1
        #predict_number = np.random.randint(1, 101)  # предполагаемое число
        if number > predict_number:
            predict_number = predict_number + (predict_number // 2)
            print(predict_number, 'больше')
        if number < predict_number:
                predict_number -= 1 
                print(predict_number, 'меньше')
        if number == predict_number:
            break  # выход из цикла если угадали
    return count


def score_game(random_predict) -> int:
   
    count_ls = []
    #np.random.seed(1)  # фиксируем сид для воспроизводимости
    random_array = np.random.randint(1, 101, size=(1000))  # загадали список чисел

    for number in random_array:
        count_ls.append(random_predict(number))

    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за:{score} попыток")
    return score

print(score_game(random_predict))
# Out:
# 49 меньше
# 48 меньше
# 47 меньше
# 46 меньше
# 45 меньше
# 44 меньше
# 43 меньше
# 42 меньше
# 41 меньше
# 40 меньше
# 39 меньше
# 38 меньше
# 37 меньше
# 36 меньше
# 35 меньше
# 34 меньше
# 33 меньше
# 32 меньше
# 31 меньше
# 30 меньше
# 29 меньше
# 28 меньше
# 27 меньше
# 26 меньше
# 25 меньше
# 24 меньше
# 23 меньше
# 22 меньше
# 21 меньше
# 20 меньше
# 19 меньше
# 18 меньше
# 17 меньше
# 16 меньше
# 15 меньше
# 14 меньше
# 13 меньше
# 12 меньше
# 11 меньше
# 10 меньше
# 9 меньше
# 8 меньше
# 7 меньше
# 6 меньше
# 5 меньше
# 4 меньше
# 3 меньше
# 2 меньше
# 75 больше
# 74 меньше
# 73 меньше
# 72 меньше
# 71 меньше
# 70 меньше
# 69 меньше
# 68 меньше
# 67 меньше
# 66 меньше
# 65 меньше
# 64 меньше
# 63 меньше
# 62 меньше
# 61 меньше
# 60 меньше
# 59 меньше
# 58 меньше
# 57 меньше
# 56 меньше
# 75 больше
# 112 больше
# 111 меньше
# 110 меньше
# 109 меньше
# 108 меньше
# 107 меньше
# 106 меньше
# 105 меньше
# 104 меньше
# 103 меньше
# 102 меньше
# 101 меньше
# 100 меньше
# ...

# %%
from word2number import w2n

print(w2n.word_to_num("twenty"))
# Out:
# 20

# %%
ozon = pd.read_excel('/Users/macbook/Documents/GitHub/SF_Petrov/OZON 16-22.xlsx')

# %%
ozon.head(3)
# Out:
#         Дата         ID                   Тип задания  \
# 0 2023-10-16  218461380  Забор товара селлеров из ПВЗ
# 1 2023-10-16  218461379  Забор товара селлеров из ПВЗ
# 2 2023-10-16  218461378  Забор товара селлеров из ПВЗ
#
#                                                Адрес доплата Отпр., шт.  \
# 0  Россия, Московская, Мирный, Россия, Московская...       —   82 Отпр.
# 1  Россия, Московская, Мирный, Россия, Московская...       —   92 Отпр.
# 2  Россия, Московская, Малаховка, Россия, Московс...       —    2 Отпр.
#
#   плотность, ₽ ОВХ, ₽  Итого, ₽
# 0            —    287     287.0
# 1            —    322     322.0
# 2            —      7       7.0

# %%
ozon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Дата          91 non-null     datetime64[ns]
#  1   ID            91 non-null     int64
#  2   Тип задания   91 non-null     object
#  3   Адрес         91 non-null     object
#  4   доплата       91 non-null     object
#  5   Отпр., шт.    91 non-null     object
#  6   плотность, ₽  91 non-null     object
#  7   ОВХ, ₽        91 non-null     object
#  8   Итого, ₽      91 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 6.5+ KB

# %%
ozon['Адрес'].unique()
# Out:
# array(['Россия, Московская, Мирный, Россия, Московская область, городской округ Люберцы, посёлок Мирный, Крымская улица, 8',
#        'Россия, Московская, Мирный, Россия, Московская область, городской округ Люберцы, посёлок Мирный, Крымская улица, 12/11',
#        'Россия, Московская, Малаховка, Россия, Московская область, городской округ Люберцы, рабочий посёлок Малаховка, Рельсовая улица, 1Г',
#        'Россия, Московская, Пехорка, Россия, Московская область, городской округ Люберцы, рабочий посёлок Малаховка, Быковское шоссе, 90Б',
#        'Россия, Московская, Малаховка, Россия, Московская область, городской округ Люберцы, рабочий посёлок Малаховка, Быковское шоссе, 37',
#        'Россия, Московская, Малаховка, Россия, Московская область, рабочий посёлок Малаховка, Быковское шоссе, 48',
#        'Россия, Московская, Малаховка, Россия, Московская область, городской округ Люберцы, рабочий посёлок Малаховка, улица Кирова, 4/1',
# ...

# %%
ozon['Дата'].unique()
# Out:
# <DatetimeArray>
# ['2023-10-16 00:00:00', '2023-10-17 00:00:00', '2023-10-21 00:00:00',
#  '2023-10-22 00:00:00']
# Length: 4, dtype: datetime64[ns]

# %%
ozon.groupby(
    by='Тип задания'
)[['Итого, ₽']].sum()
# Out:
#                               Итого, ₽
# Тип задания
# Возврат селлера в пвз           1477.0
# Доставка в ПВЗ                 13044.5
# Забор товара селлеров из ПВЗ    4019.5
